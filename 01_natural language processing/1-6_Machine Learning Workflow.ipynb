# %% [markdown]
# ## 1. 머신 러닝 워크플로우

# %% [markdown]
# 수집 - 점검 및 탐색 - 전처리 및 정제 - 모댈링 및 훈련 - 평가 - 배포

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
